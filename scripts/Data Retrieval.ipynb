# %%
import pandas as pd
from sodapy import Socrata
import json

# %%
dataset_key = 'cpkv-aajs'
total_rows = 25013
output_final_name = 'housing.json'

# %%
client = Socrata('data.lacity.org',
                 'a8aBcUA3vcl24l81OQXzi9puR',
                 username="hkoneru@usc.edu",
                 password="Dsci@2023")

# %%
# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get(dataset_key, limit=total_rows)

# %%
# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
#       zip_code address_end floor_area_l_a_building_code_definition  \
# 0        90094        6500                                    4443
# 1        90026        1950                                    2389
# 2        91343       15827                                    2631
# 3        90077         627                                    5823
# 4        91343       15803                                    2631
# ...        ...         ...                                     ...
# 25008    90094       12411                                 1494041
# 25009    90017        1000                                  137688
# 25010    90017         960                                 1015286
# 25011    90016        3333                                 1741033
# 25012    90012        1000                                 2188552
#
#                                         work_description  \
# 0      Three story single family dwelling with attcah...
# 1      NEW 3-STORY SINGLE FAMILY RESIDENCE - 2389 SQF...
# 2      NEW 34'-0" x 47'-4" TWO-STORY SINGLE FAMILY DW...
# 3      1.) SUPPLEMENTAL TO 14010-30000-03040 FOR CHAN...
# 4      NEW 34'-0" x 47'-6" TWO-STORY SINGLE FAMILY DW...
# ...                                                  ...
# 25008  New 5-story, 703 unit apartment over 1 level s...
# 25009  Mixed use builidng (Apartment/retail/parking g...
# 25010  New 64-story mixed-use Apartment and Retail bu...
# 25011  NEW 910-UNIT MIXED-USE BUILDING (CORE AND SHEL...
# 25012  NEW SEVEN STORY MIXED USE BUILDING WITH TWO LE...
#
#       :@computed_region_qz3q_ghft :@computed_region_k96s_3jcv  \
# 0                           24343                         923
# 1                           23444                         480
# 2                           18914                         121
# 3                             NaN                         NaN
# 4                           18914                         121
# ...                           ...                         ...
# 25008                       24343                         923
# 25009                       23078                         546
# 25010                         NaN                         NaN
# 25011                       23077                         667
# 25012                       22728                         548
#
#       reference_old_permit :@computed_region_kqwf_mjcx census_tract  \
# 0                19WL99310                          10      2756.02
# 1                21LA01334                           8      1974.10
# 2                21ON 2734                           2      1174.04
# 3                17VN34261                         NaN      2621.00
# 4                21ON 2735                           2      1174.04
# ...                    ...                         ...          ...
# 25008            14VN73978                          10      2756.02
# 25009            15LA56210                           9      2077.10
# 25010            20LA47304                         NaN      2077.10
# 25011            18LA05764                          12      2199.02
# 25012            18WL91190                          11      2080.00
#
#       permit_category  ... applicant_address_3 applicant_address_2  \
# 0          Plan Check  ...                 NaN                 NaN
# 1          Plan Check  ...                 NaN                 NaN
# 2          Plan Check  ...           CALABASAS                 NaN
# 3          Plan Check  ...    LOS ANGELES, CA.               #1510
# 4          Plan Check  ...           CALABASAS                 NaN
# ...               ...  ...                 ...                 ...
# 25008      Plan Check  ...                 NaN                 NaN
# 25009      Plan Check  ...                 NaN                 NaN
# 25010      Plan Check  ...     LOS ANGELES, CA           STE. 2200
# 25011      Plan Check  ...        SANTA MONICA                 203
# 25012      Plan Check  ...                 NaN                 NaN
#
#       unit_range_start address_fraction_start address_fraction_end  \
# 0                  NaN                    NaN                  NaN
# 1                  NaN                    NaN                  NaN
# 2                  NaN                    NaN                  NaN
# 3                  NaN                    NaN                  NaN
# 4                  NaN                    NaN                  NaN
# ...                ...                    ...                  ...
# 25008              NaN                    NaN                  NaN
# 25009              NaN                    NaN                  NaN
# 25010              NaN                    NaN                  NaN
# 25011              NaN                    NaN                  NaN
# 25012              NaN                    NaN                  NaN
#
#               applicant_business_name occupancy unit_range_end  \
# 0                                 NaN       NaN            NaN
# 1                                 NaN       NaN            NaN
# 2                                 NaN       NaN            NaN
# 3                                 NaN       NaN            NaN
# 4                                 NaN       NaN            NaN
# ...                               ...       ...            ...
# 25008                             NaN       NaN            NaN
# 25009                             NaN       NaN            NaN
# 25010                             NaN       NaN            NaN
# 25011                             NaN       NaN            NaN
# 25012  PALMER BEAYDRY AVE. PROPERTIES       NaN            NaN
#
#       suffix_direction project_number
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
# ...                ...            ...
# 25008              NaN            NaN
# 25009              NaN            NaN
# 25010              NaN            NaN
# 25011              NaN            NaN
# 25012              NaN            NaN
#
# [25013 rows x 57 columns]

# %%
with open(output_final_name, "w") as outfile:
    json.dump(results, outfile)
